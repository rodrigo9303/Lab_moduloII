# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N=5000
ale_x=np.random.uniform(0.,10.,N)
ale_y=np.random.uniform(0.,10.,N)
plt.plot(ale_x,ale_y,'.')

# %%
circle_r = 9.
circle_x = 5.
circle_y = 5.

Nc = 1000

phi = 2. * np.pi * np.random.rand(Nc)
r = circle_r * np.random.rand(Nc)

# %%
x = np.sqrt(r) * np.cos(phi) + circle_x
y = np.sqrt(r) * np.sin(phi) + circle_y

# %%
plt.plot(x, y, '.')
plt.xlabel(r"x", fontsize = 15)
plt.ylabel(r"y", fontsize = 15)
# Out:
# Text(0,0.5,'y')

# %%
plt.plot(ale_x,ale_y,'.')
plt.plot(x,y,'.')

# %%
def distancia(x1,x2,y1,y2):
    d = np.sqrt((x2 - x1)**2 + (y2-y1)**2)
    return d

# %%
dtot = N*(N-1)/2
dis_datos = []
dis_aleatorios = []

# %%
for i in range(N):
    for j in range(i+1,N):
        #d_d = distancia(x[i],x[j],y[i],y[j])
        d_a = distancia(ale_x[i],ale_x[j],ale_y[i],ale_y[j])
        #dis_datos.append(d_d)
        dis_aleatorios.append(d_a)

# %%
for i in range(Nc):
    for j in range(i+1,Nc):
        d_d = distancia(x[i],x[j],y[i],y[j])
        #d_a = distancia(ale_x[i],ale_x[j],ale_y[i],ale_y[j])
        dis_datos.append(d_d)
        #dis_aleatorios.append(d_a)

# %%
nbins = np.linspace(0.,np.sqrt(2)*10, 100)
data_n, data_bin,m = plt.hist(dis_datos,nbins, label='$DD(r)$')
print(nbins)
plt.legend()
# Out:
# [ 0.          0.14284985  0.28569971  0.42854956  0.57139942  0.71424927
#   0.85709913  0.99994898  1.14279884  1.28564869  1.42849855  1.5713484
#   1.71419826  1.85704811  1.99989797  2.14274782  2.28559768  2.42844753
#   2.57129739  2.71414724  2.8569971   2.99984695  3.14269681  3.28554666
#   3.42839651  3.57124637  3.71409622  3.85694608  3.99979593  4.14264579
#   4.28549564  4.4283455   4.57119535  4.71404521  4.85689506  4.99974492
#   5.14259477  5.28544463  5.42829448  5.57114434  5.71399419  5.85684405
#   5.9996939   6.14254376  6.28539361  6.42824347  6.57109332  6.71394317
#   6.85679303  6.99964288  7.14249274  7.28534259  7.42819245  7.5710423
#   7.71389216  7.85674201  7.99959187  8.14244172  8.28529158  8.42814143
#   8.57099129  8.71384114  8.856691    8.99954085  9.14239071  9.28524056
#   9.42809042  9.57094027  9.71379013  9.85663998  9.99948983 10.14233969
#  10.28518954 10.4280394  10.57088925 10.71373911 10.85658896 10.99943882
#  11.14228867 11.28513853 11.42798838 11.57083824 11.71368809 11.85653795
#  11.9993878  12.14223766 12.28508751 12.42793737 12.57078722 12.71363708
#  12.85648693 12.99933679 13.14218664 13.2850365  13.42788635 13.5707362
#  13.71358606 13.85643591 13.99928577 14.14213562]

# %%
ran_n, ran_bin, p = plt.hist(dis_aleatorios,nbins,label='RR(r)')
plt.legend()

# %%
Nest= ((N*(N-1))/(Nc*(Nc-1)))
plt.plot(data_bin[1:],Nest*(data_n/ran_n) -1, label=('Peebles=$\dfrac{1}{N_{est}^{2}}\dfrac{DD(r)}{RR(r)}-1$'))
plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
dis_da = []
for i in range(Nc):
    for j in range(N):
        d_dr = distancia(x[i],ale_x[j],y[i],ale_y[j])
        dis_da.append(d_dr)

# %%
da_n, da_bin, q = plt.hist(dis_da,nbins,label='DR(r)')
plt.legend()

# %%
plt.plot(data_bin[1:],(data_n*ran_n)/(da_n)**2,label=('Hamilton=$\dfrac{DD(r)RR(r)}{DR(r)^2}$'))
plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(data_bin[1:],1.+ Nest*data_n/ran_n -2*Nest*da_n/ran_n, label=('Landy-Szalay=$1+\dfrac{1}{N_{est}^{2}}\dfrac{DD(r)}{RR(r)}-2\dfrac{1}{N_{est}^{2}}\dfrac{DR(r)}{RR(r)}$'))
plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(data_bin[1:],Nest*((data_n)/(da_n))-1,label=('Davis-Peebles=$\dfrac{1}{N_{est}^{2}}\dfrac{DD(r)}{DR(r)}-1$'))
plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
ranillo = 2*np.pi*np.random.uniform(1.1,1.4,Nc)
rani = np.sqrt(ranillo)#**(0.5)
w = rani * np.cos(phi) + circle_x
z = rani * np.sin(phi) + circle_y
plt.plot(w,z,'.')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0,0.5,'y')

# %%
plt.plot(ale_x,ale_y,'.')
plt.plot(w,z,'.')

# %%
dis_datos_ani = []
dis_ran = []

# %%
for i in range(N):
    for j in range(i+1,N):
        #d_d = distancia(x[i],x[j],y[i],y[j])
        d_r = distancia(ale_x[i],ale_x[j],ale_y[i],ale_y[j])
        #dis_datos_ani.append(d_d)
        dis_ran.append(d_r)

# %%
for i in range(Nc):
    for j in range(i+1,Nc):
        d_d = distancia(w[i],w[j],z[i],z[j])
       # d_r = distancia(ale_x[i],ale_x[j],ale_y[i],ale_y[j])
        dis_datos_ani.append(d_d)
       # dis_ran.append(d_r)

# %%
datos_n, datos_bin, a = plt.hist(dis_datos_ani,nbins,label='$DD(r)$')
plt.legend()

# %%
random_n, random_bin, b = plt.hist(dis_ran,nbins, label='$RR(r)$')
plt.legend()

# %%
dis_dale = []
for i in range(Nc):
    for j in range(N):
        d_dar = distancia(w[i],ale_x[j],z[i],ale_y[j])
        dis_dale.append(d_dar)

# %%
dar_n, dar_bin, c = plt.hist(dis_dale,nbins,label='$DR(r)$')
plt.legend()

# %%
plt.plot(datos_bin[1:],Nest*(datos_n/random_n) -1, label=('Peebles=$\dfrac{1}{N_{est}^{2}}\dfrac{DD(r)}{RR(r)}-1$'))
plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(datos_bin[1:],(datos_n*random_n)/(dar_n)**2,label=('Hamilton=$\dfrac{DD(r)RR(r)}{DR(r)^2}$'))
plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(datos_bin[1:],1.+ Nest*datos_n/random_n -2*Nest*dar_n/random_n, label=('Landy-Szalay=$1+\dfrac{1}{N_{est}^{2}}\dfrac{DD(r)}{RR(r)}-2\dfrac{1}{N_{est}^{2}}\dfrac{DR(r)}{RR(r)}$'))

plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(datos_bin[1:],Nest*((datos_n)/(dar_n))-1,label=('Davis-Peebles=$\dfrac{1}{N_{est}^{2}}\dfrac{DD(r)}{DR(r)}-1$'))

plt.legend()
# Out:
# /home/rodrigo/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
